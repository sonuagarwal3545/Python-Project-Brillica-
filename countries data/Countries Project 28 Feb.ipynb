# %%
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
countries=pd.read_csv("D:\Edu File\Brillica Services project\EDA Python Data Countries\countries.csv")

# %%
countries
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# ...           ...       ...   ...             ...         ...           ...
# 1699     Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700     Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701     Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702     Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703     Zimbabwe    Africa  2007          43.487    12311143    469.709298
#
# [1704 rows x 6 columns]

# %%
countries.describe()
# Out:
#              year  lifeExpectancy    population   gdpPerCapita
# count  1704.00000     1704.000000  1.704000e+03    1704.000000
# mean   1979.50000       59.474439  2.960121e+07    7215.327081
# std      17.26533       12.917107  1.061579e+08    9857.454543
# min    1952.00000       23.599000  6.001100e+04     241.165876
# 25%    1965.75000       48.198000  2.793664e+06    1202.060309
# 50%    1979.50000       60.712500  7.023596e+06    3531.846988
# 75%    1993.25000       70.845500  1.958522e+07    9325.462346
# max    2007.00000       82.603000  1.318683e+09  113523.132900

# %%
countries.isnull().sum()
# Out:
# country           0
# continent         0
# year              0
# lifeExpectancy    0
# population        0
# gdpPerCapita      0
# dtype: int64

# %%
countries.year.unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007], dtype=int64)

# %%
countries.lifeExpectancy.unique()
# Out:
# array([28.801, 30.332, 31.997, ..., 46.809, 39.989, 43.487])

# %%
countries.population.unique()
# Out:
# array([ 8425333,  9240934, 10267083, ..., 11404948, 11926563, 12311143],
#       dtype=int64)

# %%
countries.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
countries.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
Co=countries.groupby(["country","population"])["lifeExpectancy"].sum()

# %%
Co
# Out:
# country      population
# Afghanistan  8425333       28.801
#              9240934       30.332
#              10267083      31.997
#              11537966      34.020
#              12881816      39.854
#                             ...
# Zimbabwe     9216418       62.351
#              10704340      60.377
#              11404948      46.809
#              11926563      39.989
#              12311143      43.487
# Name: lifeExpectancy, Length: 1704, dtype: float64

# %%
Co.head(500)
# Out:
# country      population
# Afghanistan  8425333       28.801
#              9240934       30.332
#              10267083      31.997
#              11537966      34.020
#              12881816      39.854
#                             ...
# Eritrea      1820319       42.189
#              2260187       44.142
#              2512642       44.535
#              2637297       43.890
#              2915959       46.453
# Name: lifeExpectancy, Length: 500, dtype: float64

# %%
Co.describe()
# Out:
# count    1704.000000
# mean       59.474439
# std        12.917107
# min        23.599000
# 25%        48.198000
# 50%        60.712500
# 75%        70.845500
# max        82.603000
# Name: lifeExpectancy, dtype: float64

# %%
Co=countries.groupby(["continent", "population"])["lifeExpectancy"].max()

# %%
Co
# Out:
# continent  population
# Africa     60011         46.471
#            61325         48.945
#            63149         34.812
#            65345         51.893
#            70787         54.425
#                           ...
# Oceania    16257249      76.320
#            17481977      77.560
#            18565243      78.830
#            19546792      80.370
#            20434176      81.235
# Name: lifeExpectancy, Length: 1704, dtype: float64

# %%
Co.describe()
# Out:
# count    1704.000000
# mean       59.474439
# std        12.917107
# min        23.599000
# 25%        48.198000
# 50%        60.712500
# 75%        70.845500
# max        82.603000
# Name: lifeExpectancy, dtype: float64

# %%
countries.where(countries.lifeExpectancy ==countries.lifeExpectancy.max())[["country","year","lifeExpectancy"]].dropna()
# Out:
#     country    year  lifeExpectancy
# 803   Japan  2007.0          82.603

# %%
countries.where(countries.lifeExpectancy ==countries.lifeExpectancy.min())[["country","year","lifeExpectancy"]].dropna()
# Out:
#      country    year  lifeExpectancy
# 1292  Rwanda  1992.0          23.599

# %%
countries[['country','year','lifeExpectancy']][(countries.country=="India")&(countries.year==2007)]
# Out:
#     country  year  lifeExpectancy
# 707   India  2007          64.698

# %%
countries[['country','year','lifeExpectancy']][(countries.country=="China")&(countries.year==2007)]
# Out:
#     country  year  lifeExpectancy
# 299   China  2007          72.961

# %%
countries[['country','year','lifeExpectancy']][(countries.country=="China")&(countries.year==1952)]
# Out:
#     country  year  lifeExpectancy
# 288   China  1952            44.0

# %%
countries[['country','year','lifeExpectancy']][(countries.country=="Pakistan")&(countries.year==2007)]
# Out:
#        country  year  lifeExpectancy
# 1175  Pakistan  2007          65.483

# %%
countries[['country','year','lifeExpectancy']][(countries.country=="India")&(countries.year==1952)]
# Out:
#     country  year  lifeExpectancy
# 696   India  1952          37.373

# %%
countries[['country','year','population']][(countries.country=="India")&(countries.year==1952)]
# Out:
#     country  year  population
# 696   India  1952   372000000

# %%
countries[['country','year','population']][(countries.country=="India")&(countries.year==2007)]
# Out:
#     country  year  population
# 707   India  2007  1110396331

# %%
countries[['country','year','population']][(countries.country=="China")&(countries.year==1952)]
# Out:
#     country  year  population
# 288   China  1952   556263527

# %%
countries[['country','year','population']][(countries.country=="China")&(countries.year==2007)]
# Out:
#     country  year  population
# 299   China  2007  1318683096

# %%
countries[['country','year','population']][(countries.continent=="Asia")&(countries.year==2007)]
# Out:
#                  country  year  population
# 11           Afghanistan  2007    31889923
# 95               Bahrain  2007      708573
# 107           Bangladesh  2007   150448339
# 227             Cambodia  2007    14131858
# 299                China  2007  1318683096
# 671     Hong Kong, China  2007     6980412
# 707                India  2007  1110396331
# 719            Indonesia  2007   223547000
# 731                 Iran  2007    69453570
# 743                 Iraq  2007    27499638
# 767               Israel  2007     6426679
# 803                Japan  2007   127467972
# 815               Jordan  2007     6053193
# 839     Korea, Dem. Rep.  2007    23301725
# 851          Korea, Rep.  2007    49044790
# 863               Kuwait  2007     2505559
# 875              Lebanon  2007     3921278
# 947             Malaysia  2007    24821286
# 1007            Mongolia  2007     2874127
# 1055             Myanmar  2007    47761980
# 1079               Nepal  2007    28901790
# ...

# %%
ap=countries[['country','year','population']][(countries.continent=="Asia")&(countries.year==1952)]

# %%
ap.describe()
# Out:
#          year    population
# count    33.0  3.300000e+01
# mean   1952.0  4.228356e+07
# std       0.0  1.132267e+08
# min    1952.0  1.204470e+05
# 25%    1952.0  1.620914e+06
# 50%    1952.0  7.982342e+06
# 75%    1952.0  2.128940e+07
# max    1952.0  5.562635e+08

# %%
ap
# Out:
#                  country  year  population
# 0            Afghanistan  1952     8425333
# 84               Bahrain  1952      120447
# 96            Bangladesh  1952    46886859
# 216             Cambodia  1952     4693836
# 288                China  1952   556263527
# 660     Hong Kong, China  1952     2125900
# 696                India  1952   372000000
# 708            Indonesia  1952    82052000
# 720                 Iran  1952    17272000
# 732                 Iraq  1952     5441766
# 756               Israel  1952     1620914
# 792                Japan  1952    86459025
# 804               Jordan  1952      607914
# 828     Korea, Dem. Rep.  1952     8865488
# 840          Korea, Rep.  1952    20947571
# 852               Kuwait  1952      160000
# 864              Lebanon  1952     1439529
# 936             Malaysia  1952     6748378
# 996             Mongolia  1952      800663
# 1044             Myanmar  1952    20092996
# 1068               Nepal  1952     9182536
# ...

# %%
ap=countries[['country','year',"gdpPerCapita"]][(countries.country=="India")&(countries.year==1952)]

# %%
ap
# Out:
#     country  year  gdpPerCapita
# 696   India  1952    546.565749

# %%
ap=countries[['country','year',"gdpPerCapita"]][(countries.country=="India")&(countries.year==2007)]

# %%
ap
# Out:
#     country  year  gdpPerCapita
# 707   India  2007   2452.210407

# %%
clf=countries[["country","lifeExpectancy"]][countries.year==2007].sort_values(by="lifeExpectancy",ascending=False).head(50)

# %%
clf
# Out:
#                      country  lifeExpectancy
# 803                    Japan          82.603
# 671         Hong Kong, China          82.208
# 695                  Iceland          81.757
# 1487             Switzerland          81.701
# 71                 Australia          81.235
# 1427                   Spain          80.941
# 1475                  Sweden          80.884
# 767                   Israel          80.745
# 539                   France          80.657
# 251                   Canada          80.653
# 779                    Italy          80.546
# 1103             New Zealand          80.204
# 1151                  Norway          80.196
# 1367               Singapore          79.972
# 83                   Austria          79.829
# 1091             Netherlands          79.762
# 599                   Greece          79.483
# 119                  Belgium          79.441
# 1607          United Kingdom          79.425
# 575                  Germany          79.406
# ...

# %%
clf=countries[["country","gdpPerCapita"]][countries.year==2007].sort_values(by="gdpPerCapita",ascending=False).head(10)

# %%
clf
# Out:
#                country  gdpPerCapita
# 1151            Norway   49357.19017
# 863             Kuwait   47306.98978
# 1367         Singapore   47143.17964
# 1619     United States   42951.65309
# 755            Ireland   40675.99635
# 671   Hong Kong, China   39724.97867
# 1487       Switzerland   37506.41907
# 1091       Netherlands   36797.93332
# 251             Canada   36319.23501
# 695            Iceland   36180.78919

# %%
clf=countries[["country","gdpPerCapita"]][countries.year==1952].sort_values(by="gdpPerCapita",ascending=False).head(10)

# %%
clf
# Out:
#              country   gdpPerCapita
# 852           Kuwait  108382.352900
# 1476     Switzerland   14734.232750
# 1608   United States   13990.482080
# 240           Canada   11367.161120
# 1092     New Zealand   10556.575660
# 1140          Norway   10095.421720
# 60         Australia   10039.595640
# 1596  United Kingdom    9979.508487
# 84           Bahrain    9867.084765
# 408          Denmark    9692.385245

# %%
clf=countries[["continent","gdpPerCapita"]][countries.year==2007].sort_values(by="gdpPerCapita",ascending=False).head(5)

# %%
clf
# Out:
#      continent  gdpPerCapita
# 1151    Europe   49357.19017
# 863       Asia   47306.98978
# 1367      Asia   47143.17964
# 1619  Americas   42951.65309
# 755     Europe   40675.99635

# %%
clf=countries[["continent","population","gdpPerCapita"]][countries.year==2007].sort_values(by="gdpPerCapita",ascending=False).head(5)

# %%
clf
# Out:
#      continent  population  gdpPerCapita
# 1151    Europe     4627926   49357.19017
# 863       Asia     2505559   47306.98978
# 1367      Asia     4553009   47143.17964
# 1619  Americas   301139947   42951.65309
# 755     Europe     4109086   40675.99635

# %%
clf=countries[[ "lifeExpectancy","population","gdpPerCapita"]][countries.year==2007].sort_values(by="gdpPerCapita",ascending=True).head(5)

# %%
clf
# Out:
#       lifeExpectancy  population  gdpPerCapita
# 335           46.462    64606759    277.551859
# 899           45.678     3193942    414.507341
# 215           49.580     8390505    430.070692
# 1703          43.487    12311143    469.709298
# 635           46.388     1472041    579.231743

# %%
sns.catplot(x = 'country', y = 'gdpPerCapita', data = ap, kind='bar')
plt.show()
